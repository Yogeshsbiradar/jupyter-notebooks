# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
# Out:
# Using TensorFlow backend.

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 26 documents
# 6 classes ['age', 'goodbye', 'greeting', 'hours', 'name', 'shop']
# 48 unique lemmatized words ['a', 'age', 'am', 'anyone', 'are', 'buy', 'call', 'could', 'cya', 'day', 'do', 'eat', 'get', 'good', 'goodbye', 'guy', 'have', 'hello', 'hi', 'hour', 'how', 'i', 'id', 'is', 'later', 'leaving', 'like', 'menu', 'name', 'of', 'old', 'on', 'open', 'operation', 'reccommend', 'see', 'should', 'something', 'the', 'there', 'tim', 'to', 'up', 'what', 'whats', 'when', 'you', 'your']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 26/26 [==============================] - 4s 144ms/step - loss: 1.7446 - accuracy: 0.1538
# Epoch 2/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.8664 - accuracy: 0.0769
# Epoch 3/200
# 26/26 [==============================] - 0s 2ms/step - loss: 1.7398 - accuracy: 0.2692
# Epoch 4/200
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6268 - accuracy: 0.2692
# Epoch 5/200
# 26/26 [==============================] - 0s 2ms/step - loss: 1.6336 - accuracy: 0.3846
# Epoch 6/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.5740 - accuracy: 0.4615
# Epoch 7/200
# 26/26 [==============================] - 0s 2ms/step - loss: 1.4530 - accuracy: 0.4615
# Epoch 8/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.4169 - accuracy: 0.5000
# Epoch 9/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.4904 - accuracy: 0.4231
# Epoch 10/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.4092 - accuracy: 0.4231
# Epoch 11/200
# 26/26 [==============================] - 0s 2ms/step - loss: 1.2733 - accuracy: 0.5000
# Epoch 12/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.1521 - accuracy: 0.6923
# Epoch 13/200
# 26/26 [==============================] - 0s 601us/step - loss: 1.0916 - accuracy: 0.7308
# Epoch 14/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.2007 - accuracy: 0.5385
# Epoch 15/200
# 26/26 [==============================] - 0s 1ms/step - loss: 1.2132 - accuracy: 0.4231
# Epoch 16/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.8153 - accuracy: 0.7692
# Epoch 17/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.9308 - accuracy: 0.7692
# Epoch 18/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8624 - accuracy: 0.7692
# Epoch 19/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.8621 - accuracy: 0.8462
# Epoch 20/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.8781 - accuracy: 0.6538
# Epoch 21/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.6640 - accuracy: 0.7308
# Epoch 22/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7431 - accuracy: 0.7308
# Epoch 23/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.6111 - accuracy: 0.8077
# Epoch 24/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.9231
# Epoch 25/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.7692
# Epoch 26/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.5101 - accuracy: 0.8077
# Epoch 27/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3877 - accuracy: 0.9231
# Epoch 28/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6637 - accuracy: 0.6923
# Epoch 29/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.5546 - accuracy: 0.8077
# Epoch 30/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.8462
# Epoch 31/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8846
# Epoch 32/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8077
# Epoch 33/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.4309 - accuracy: 0.8462
# Epoch 34/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2890 - accuracy: 0.8846
# Epoch 35/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.9615
# Epoch 36/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3767 - accuracy: 0.8846
# Epoch 37/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3630 - accuracy: 0.8846
# Epoch 38/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.9231
# Epoch 39/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.9615
# Epoch 40/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2754 - accuracy: 0.9615
# Epoch 41/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.9231
# Epoch 42/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.9231
# Epoch 43/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.3441 - accuracy: 0.8462
# Epoch 44/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9615
# Epoch 45/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2098 - accuracy: 1.0000
# Epoch 46/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1688 - accuracy: 0.9615
# Epoch 47/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2288 - accuracy: 0.9231
# Epoch 48/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9615
# Epoch 49/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2386 - accuracy: 0.9231
# Epoch 50/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.2082 - accuracy: 0.9615
# Epoch 51/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1968 - accuracy: 0.9615
# Epoch 52/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 1.0000
# Epoch 53/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1170 - accuracy: 1.0000
# Epoch 54/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0617 - accuracy: 1.0000
# Epoch 55/200
# 26/26 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 1.0000
# Epoch 56/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.1793 - accuracy: 0.9615
# Epoch 57/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1467 - accuracy: 0.9615
# Epoch 58/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0695 - accuracy: 1.0000
# Epoch 59/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2366 - accuracy: 0.9615
# Epoch 60/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 61/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1568 - accuracy: 1.0000
# Epoch 62/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 63/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 1.0000
# Epoch 64/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2236 - accuracy: 0.9615
# Epoch 65/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 66/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0904 - accuracy: 0.9615
# Epoch 67/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0673 - accuracy: 1.0000
# Epoch 68/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 69/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0901 - accuracy: 0.9615
# Epoch 70/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1305 - accuracy: 0.9615
# Epoch 71/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2033 - accuracy: 0.9615
# Epoch 72/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0626 - accuracy: 1.0000
# Epoch 73/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 74/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1554 - accuracy: 0.9231
# Epoch 75/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9615
# Epoch 76/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 77/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 78/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.1462 - accuracy: 0.9615
# Epoch 79/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0928 - accuracy: 0.9615
# Epoch 80/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9615
# Epoch 81/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1782 - accuracy: 0.9231
# Epoch 82/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 83/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 84/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0591 - accuracy: 1.0000
# Epoch 85/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1000 - accuracy: 0.9615
# Epoch 86/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 87/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 0.9615
# Epoch 88/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 89/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0489 - accuracy: 0.9615
# Epoch 90/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0673 - accuracy: 1.0000
# Epoch 91/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0623 - accuracy: 0.9615
# Epoch 92/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 1.0000
# Epoch 93/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 94/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0628 - accuracy: 1.0000
# Epoch 95/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.2014 - accuracy: 0.9231
# Epoch 96/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 97/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1009 - accuracy: 0.9615
# Epoch 98/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0757 - accuracy: 1.0000
# Epoch 99/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1434 - accuracy: 0.9231
# Epoch 100/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9231
# Epoch 101/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0629 - accuracy: 1.0000
# Epoch 102/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0833 - accuracy: 0.9615
# Epoch 103/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0483 - accuracy: 1.0000
# Epoch 104/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0603 - accuracy: 0.9615
# Epoch 105/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0760 - accuracy: 0.9615
# Epoch 106/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 107/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 108/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 109/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0389 - accuracy: 1.0000
# Epoch 110/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 111/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0717 - accuracy: 0.9615
# Epoch 112/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0637 - accuracy: 1.0000
# Epoch 113/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 114/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9615
# Epoch 115/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 116/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0720 - accuracy: 1.0000
# Epoch 117/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0561 - accuracy: 0.9615
# Epoch 118/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 119/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 120/200
# 26/26 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.00 - 0s 601us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 121/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 122/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0219 - accuracy: 1.0000
# Epoch 123/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0929 - accuracy: 0.9615
# Epoch 124/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0761 - accuracy: 0.9615
# Epoch 125/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 126/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 127/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 128/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 129/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 130/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 131/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 132/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 133/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 134/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 135/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 136/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 137/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 138/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0632 - accuracy: 1.0000
# Epoch 139/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 1.0000
# Epoch 140/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 141/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 142/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 143/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0263 - accuracy: 1.0000
# Epoch 144/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 145/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0606 - accuracy: 0.9615
# Epoch 146/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 147/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 148/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0459 - accuracy: 1.0000
# Epoch 149/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 150/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 151/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 152/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 153/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 154/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.1241 - accuracy: 0.9615
# Epoch 155/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 156/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 157/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0416 - accuracy: 0.9615
# Epoch 158/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 1.0000
# Epoch 159/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0568 - accuracy: 0.9615
# Epoch 160/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 161/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 162/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 163/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 164/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 165/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 166/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 167/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 0.9615
# Epoch 168/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0973 - accuracy: 0.9615
# Epoch 169/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0605 - accuracy: 0.9615
# Epoch 170/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 171/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0211 - accuracy: 1.0000
# Epoch 172/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 1.0000
# Epoch 173/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 174/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9615
# Epoch 175/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 176/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9615
# Epoch 177/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 178/200
# 26/26 [==============================] - 0s 601us/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 179/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 180/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9615
# Epoch 181/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 182/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 183/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 184/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 185/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 186/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 187/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 188/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 189/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 1.0000
# Epoch 190/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 191/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 192/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 193/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 194/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 195/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0464 - accuracy: 1.0000
# Epoch 196/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 197/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 198/200
# 26/26 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 199/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 200/200
# 26/26 [==============================] - 0s 1ms/step - loss: 0.0824 - accuracy: 0.9615
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("Hello")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
